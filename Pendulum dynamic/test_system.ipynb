# %%
import numpy as np
import pandas as pd
import VP_oscillator_predictor as VPs
import matplotlib.pyplot as plt

# %%
params={'a':2,
        'b':-0.8,
        'c':2,
        'd':-10,
        'delta_t':0.01}
Predictor=VPs.VP_O(params)

# %%
x0,y0=0.5,0.5
T=100
u=10.0*np.cos([i*np.pi/T for i in range(T)])
x,y=Predictor.sim(x0,y0,T,u)

# %%
plt.plot(x,label='x')
plt.plot(y,label='y')
plt.legend()
